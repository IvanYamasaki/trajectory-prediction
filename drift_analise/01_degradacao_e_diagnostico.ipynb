# %% [markdown]
# # Capítulo 1 — Degradação do modelo e diagnóstico descritivo
#
# Este capítulo consolida a **granularidade por jogo / janela / trajetória**, o contexto cinemático (KS, Wasserstein) e as figuras descritivas de ADE (incluindo cauda e correlações).
#
# **Pré-requisitos** (rodar na raiz do repositório, com dados locais):
#
# 1. `main_plot_covariate_shift()` (módulo `chapter01_descriptive_pipeline`) — gera CSVs em `covariate_shift_out/` e PNGs em `Relas/results/drift/01_degradacao_e_diagnostico/`.
# 2. `model_analise/compute_trajectory_errors.py` — gera `covariate_shift_out/trajectory_errors_sample.*`.
#
# Em seguida, as figuras PDF bilíngues (PT/EN) são produzidas por `run_descriptive_figures()` no mesmo módulo.

# %%
import os, sys
from pathlib import Path
ROOT = Path.cwd().resolve()
while ROOT != ROOT.parent and not (ROOT / 'requirements.txt').exists():
    ROOT = ROOT.parent
os.chdir(ROOT)
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))
from drift_analise.drift_output_paths import CH01, CH02, CH03, CH04, COVARIATE_SHIFT_OUT, ensure_chapter_dirs
from drift_analise.notebook_utils import display_pdf, display_png, display_sorted_glob
ensure_chapter_dirs()
from drift_analise.chapter01_descriptive_pipeline import main_plot_covariate_shift as run_plot_covariate_shift
run_plot_covariate_shift()

# %% [markdown]
# ## Figuras descritivas (PDF PT/EN)

# %%
import os, sys
from pathlib import Path
ROOT = Path.cwd().resolve()
while ROOT != ROOT.parent and not (ROOT / 'requirements.txt').exists():
    ROOT = ROOT.parent
os.chdir(ROOT)
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))
from drift_analise.drift_output_paths import CH01, CH02, CH03, CH04, COVARIATE_SHIFT_OUT, ensure_chapter_dirs
from drift_analise.notebook_utils import display_pdf, display_png, display_sorted_glob
ensure_chapter_dirs()
from drift_analise.chapter01_descriptive_pipeline import run_descriptive_figures
run_descriptive_figures()

# %% [markdown]
# ## Visualização inline (ordem alfabética de arquivo)

# %%
import os, sys
from pathlib import Path
ROOT = Path.cwd().resolve()
while ROOT != ROOT.parent and not (ROOT / 'requirements.txt').exists():
    ROOT = ROOT.parent
os.chdir(ROOT)
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))
from drift_analise.drift_output_paths import CH01, CH02, CH03, CH04, COVARIATE_SHIFT_OUT, ensure_chapter_dirs
from drift_analise.notebook_utils import display_pdf, display_png, display_sorted_glob
ensure_chapter_dirs()
# display_sorted_glob(CH01, '*.pdf')
display_sorted_glob(CH01, '*.png')

# %% [markdown]
# ## Artefatos tabulares em `covariate_shift_out/`

# %%
import os, sys
from pathlib import Path
ROOT = Path.cwd().resolve()
while ROOT != ROOT.parent and not (ROOT / 'requirements.txt').exists():
    ROOT = ROOT.parent
os.chdir(ROOT)
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))
from drift_analise.drift_output_paths import CH01, CH02, CH03, CH04, COVARIATE_SHIFT_OUT, ensure_chapter_dirs
from drift_analise.notebook_utils import display_pdf, display_png, display_sorted_glob
ensure_chapter_dirs()
import pandas as pd
for name in ('per_game_context.csv', 'per_window_drift.csv', 'ks_wd_per_dataset.csv'):
    p = COVARIATE_SHIFT_OUT / name
    print(p, 'exists=', p.exists())
    if p.exists():
        display(pd.read_csv(p).head())
