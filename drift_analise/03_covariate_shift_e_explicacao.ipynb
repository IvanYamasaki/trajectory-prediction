# %% [markdown]
# # Capítulo 3 — Covariate shift e explicação do excesso de erro
#
# Importance weighting (LSIF), visualizações e validação por **divisão** SSL.

# %%
import os, sys
from pathlib import Path
ROOT = Path.cwd().resolve()
while ROOT != ROOT.parent and not (ROOT / 'requirements.txt').exists():
    ROOT = ROOT.parent
os.chdir(ROOT)
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))
from drift_analise.drift_output_paths import CH01, CH02, CH03, CH04, COVARIATE_SHIFT_OUT, ensure_chapter_dirs
from drift_analise.notebook_utils import display_pdf, display_png, display_sorted_glob
ensure_chapter_dirs()
from drift_analise.chapter03_visuals import main_compute_importance_weights as run_iw
run_iw()

# %%
import os, sys
from pathlib import Path
ROOT = Path.cwd().resolve()
while ROOT != ROOT.parent and not (ROOT / 'requirements.txt').exists():
    ROOT = ROOT.parent
os.chdir(ROOT)
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))
from drift_analise.drift_output_paths import CH01, CH02, CH03, CH04, COVARIATE_SHIFT_OUT, ensure_chapter_dirs
from drift_analise.notebook_utils import display_pdf, display_png, display_sorted_glob
ensure_chapter_dirs()
from drift_analise.chapter03_visuals import run_iw_figures, run_division_validation
run_iw_figures()
run_division_validation()

# %% [markdown]
# **Nota:** as figuras IW e a análise por divisão rodam na célula anterior (`chapter03_visuals`).

# %% [markdown]
# ## Figuras

# %%
import os, sys
from pathlib import Path
ROOT = Path.cwd().resolve()
while ROOT != ROOT.parent and not (ROOT / 'requirements.txt').exists():
    ROOT = ROOT.parent
os.chdir(ROOT)
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))
from drift_analise.drift_output_paths import CH01, CH02, CH03, CH04, COVARIATE_SHIFT_OUT, ensure_chapter_dirs
from drift_analise.notebook_utils import display_pdf, display_png, display_sorted_glob
ensure_chapter_dirs()
display_sorted_glob(CH03, '*.pdf')

# %% [markdown]
# ## CSVs principais

# %%
import os, sys
from pathlib import Path
ROOT = Path.cwd().resolve()
while ROOT != ROOT.parent and not (ROOT / 'requirements.txt').exists():
    ROOT = ROOT.parent
os.chdir(ROOT)
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))
from drift_analise.drift_output_paths import CH01, CH02, CH03, CH04, COVARIATE_SHIFT_OUT, ensure_chapter_dirs
from drift_analise.notebook_utils import display_pdf, display_png, display_sorted_glob
ensure_chapter_dirs()
import pandas as pd
for p in sorted(CH03.glob('*.csv')):
    print(p.name)
    display(pd.read_csv(p).head())
