# %% [markdown]
# # Capítulo 2 — Detecção de drift no stream temporal
#
# Roda os detectores online (ADWIN, Page-Hinkley) sobre o stream completo de erros por trajetória e gera os PDFs `6_concept_drift_*`.
#
# Em seguida, a varredura de calibração `sweep_concept_drift_calibration` produz a tabela usada para escolher parâmetros (esta etapa fica **aqui**; o capítulo 4 apenas consome os resultados).

# %%
import os, sys
from pathlib import Path
ROOT = Path.cwd().resolve()
while ROOT != ROOT.parent and not (ROOT / 'requirements.txt').exists():
    ROOT = ROOT.parent
os.chdir(ROOT)
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))
from drift_analise.drift_output_paths import CH01, CH02, CH03, CH04, COVARIATE_SHIFT_OUT, ensure_chapter_dirs
from drift_analise.notebook_utils import display_pdf, display_png, display_sorted_glob
ensure_chapter_dirs()
from drift_analise.chapter02_deteccao_pipeline import main_replot_concept_drift as run_replot
run_replot()

# %%
import os, sys
from pathlib import Path
ROOT = Path.cwd().resolve()
while ROOT != ROOT.parent and not (ROOT / 'requirements.txt').exists():
    ROOT = ROOT.parent
os.chdir(ROOT)
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))
from drift_analise.drift_output_paths import CH01, CH02, CH03, CH04, COVARIATE_SHIFT_OUT, ensure_chapter_dirs
from drift_analise.notebook_utils import display_pdf, display_png, display_sorted_glob
ensure_chapter_dirs()
from drift_analise.chapter02_deteccao_pipeline import main_sweep_concept_drift_calibration as run_sweep
run_sweep()

# %% [markdown]
# ## PDFs gerados

# %%
import os, sys
from pathlib import Path
ROOT = Path.cwd().resolve()
while ROOT != ROOT.parent and not (ROOT / 'requirements.txt').exists():
    ROOT = ROOT.parent
os.chdir(ROOT)
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))
from drift_analise.drift_output_paths import CH01, CH02, CH03, CH04, COVARIATE_SHIFT_OUT, ensure_chapter_dirs
from drift_analise.notebook_utils import display_pdf, display_png, display_sorted_glob
ensure_chapter_dirs()
display_sorted_glob(CH02, '*.pdf')

# %% [markdown]
# ## Tabelas CSV

# %%
import os, sys
from pathlib import Path
ROOT = Path.cwd().resolve()
while ROOT != ROOT.parent and not (ROOT / 'requirements.txt').exists():
    ROOT = ROOT.parent
os.chdir(ROOT)
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))
from drift_analise.drift_output_paths import CH01, CH02, CH03, CH04, COVARIATE_SHIFT_OUT, ensure_chapter_dirs
from drift_analise.notebook_utils import display_pdf, display_png, display_sorted_glob
ensure_chapter_dirs()
import pandas as pd
from pathlib import Path
for p in sorted(CH02.glob('*.csv')):
    print(p.name)
    display(pd.read_csv(p).head())
